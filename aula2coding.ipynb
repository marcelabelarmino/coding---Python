# %%
numero= input('Digite um número:')
print('O número informado foi:', numero)
# Out:
# Digite um número:5
# O número informado foi: 5

# %%
n1 = input('Informe o primeiro número:')
n2 = input('Informe o segundo número:')
print(int(n1)+int (n2))
# Out:
# Informe o primeiro número:5
# Informe o segundo número:6
# 11

# %%
n1 = int (input ('Digite a primeira nota: '))
n2 = int (input ('Digite a segunda nota: '))
n3 = int (input ('Digite a terceira nota: '))
m=(n1+n2+n3)/3
print ('O resultado da média é:',m)
# Out:
# Digite a primeira nota: 6
# Digite a segunda nota: 7
# Digite a terceira nota: 8
# O resultado da média é: 7.0

# %%
sh=int(input('Quanto você ganha por hora?'))
h=int(input('Quantas horas você trabalhou esse mês?'))
r=sh*h
print('Seu salário será de: R$',r,'reais.')
# Out:
# Quanto você ganha por hora?40
# Quantas horas você trabalhou esse mês?100
# Seu salário será de: R$ 4000 reais.

# %%
p = int (input ('Digite o peso:'))
pe = p-50
m=pe*4
print ('Seu excesso foi de',pe,'kilos.')
print ('Sua multa é de: R$',m,'reais.')
# Out:
# Digite o peso:50
